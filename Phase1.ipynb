# %% [markdown]
# # Phase 1: Rubric-Aligned Epileptic Seizure Project
#
# ## Dataset Explanation
# - Dataset: Epileptic Seizure Recognition
# - Raw structure: index-like column + `X1..X178` + target `y`
# - Original labels: `y in {1,2,3,4,5}`
# - Binary mapping used: `Seizure = (y == 1)`, `Non-Seizure = (y in {2,3,4,5})`
#
# This notebook is organized to directly match grading rubric sections.

# %% [markdown]
# ## Rubric Coverage Notes
# 1. **Preprocessing**: visualization, missing-value treatment, binning, full descriptive stats, covariance/correlation/heatmap, chi-square, t-test, ANOVA.
# 2. **Feature Reduction & Selection**: PCA, Kernel PCA, LDA projection, SVD, feature-selection examples.
# 3. **Model Implementations**: Naive Bayesian, Bayesian Belief Network, Decision Tree (entropy), LDA classifier, Neural Network, K-NN (two distances), Logistic Regression, Linear Regression.
# 4. **Evaluations**: 80/20 split, K-fold average accuracy, confusion matrix, accuracy/error/precision/recall/F1/ROC, regression metrics (MAE, RMSE, R², Willmott, NSE, Legates-McCabe).
# 5. **Interpretation**: overfitting/underfitting curves and comments for each model.
# 6. **Charts**: generated **after final output table** as requested.
# 7. **Related Work + References**: starter tables included; fill your cited papers before submission.

# %%
import os
import urllib.request

# If opened directly from GitHub in Colab, phase1.py may not exist locally yet.
PHASE1_FILE = 'phase1.py'
PHASE1_URL = 'https://raw.githubusercontent.com/adhamhaithameid/epileptic-seizure-recognition/experimental/new-stuff-migration/phase1.py'

if not os.path.exists(PHASE1_FILE):
    urllib.request.urlretrieve(PHASE1_URL, PHASE1_FILE)
    print(f'Downloaded {PHASE1_FILE} from branch source.')
else:
    print(f'Using local {PHASE1_FILE}.')

# %%
from phase1 import run_phase1_pipeline

# Main execution (rubric-aligned).
outputs = run_phase1_pipeline(show_plots=True)

# %% [markdown]
# ## Final Submission Reminder (Based on Rubric)
# - Fill the **Related Work** table with real paper results from your domain.
# - Complete the **References** section with proper citations (not placeholders).
# - Keep screenshots/figures from final charts in your report if required by your TA.
